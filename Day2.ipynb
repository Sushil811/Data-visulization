# %%
 
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
 from numpy.random import randn , randint , uniform , sample

# %%
df=pd.DataFrame(randn(10,4), columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.773756  1.543904 -0.491200  1.283525
# 1  0.824186 -0.031337  0.449487 -1.997644
# 2  0.041997 -0.569472 -2.407553 -1.312391
# 3 -0.429516  0.764386 -0.200439  0.072922
# 4  0.067926  0.254319  1.026738 -0.139661
# 5 -1.456315  0.002448  0.698347  0.063792
# 6  0.362292 -0.426014 -0.640948 -1.430196
# 7  1.148413  1.678241 -1.574621  0.215844
# 8  1.379694  0.806550  0.964058  0.188428
# 9 -1.132224 -1.548377 -1.891771  0.796447

# %%
df.plot(kind='bar',figsize=(10,10))
plt.title("bar plot")
plt.show()

# %% [markdown]
#  #yesterday last question

# %%
 
#Create a 3 by 3 subplots:
x = [1,2,3,4]
y1 = [4,3,2,1]
y2 = [10,20,30,40]
y3 = [40,30,20,10]
y4 = [1,2,1,2]
y5 = [40,70,90,70]
 
 
plt.subplot(2,3,1)
plt.plot(x,y1)
plt.title('Plot1')
plt.subplot(2,3,2)
plt.plot(x,y2)
plt.title('Plot2')
plt.subplot(2,3,3)
plt.plot(x,y3)
plt.title('Plot3')
plt.subplot(2,3,4)
plt.plot(x,y4)
plt.title('Plot4')
plt.subplot(2,3,5)
plt.plot(x,y5)
plt.title('Plot5')
# Out:
# Text(0.5, 1.0, 'Plot5')
