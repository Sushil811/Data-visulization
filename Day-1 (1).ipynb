# %%
import numpy as np
import pandas as pd
import seaborn as sns


import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Question-1

# %%
#plot a line plot between a and b:
a=np.arange(40,50)
b=np.arange(50,60)
plt.title('Line plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.plot(a,b)

# %% [markdown]
# # Question-2:

# %%
#Plot a line plot showing the sales trend in company 1 and 2:

days = [1,2,3,4,5,6,7] #days of d week
sales_1 = [160,150,140,145,175,165,180] #sales of company1
sales_2 = [70,90,160,150,140,145,175]  #sales of company2
plt.title('sales trend in company', color='r')
plt.xlabel('Days')
plt.ylabel('Sales')
plt.plot(sales_1,'go', linestyle='dashed', linewidth=1, markersize=3)
plt.plot(sales_2,'bo', linestyle='dashed', linewidth=1, markersize=3)

# %% [markdown]
# ### Question-3

# %%
x=np.arange(0,10)
y=x*x
plt.title('Line Plot', color='b')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.plot(x,y,'bo', linestyle='dashed', linewidth=1, markersize=3)
plt.show()
